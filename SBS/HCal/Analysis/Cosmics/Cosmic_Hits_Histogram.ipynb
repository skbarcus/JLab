# %%
import numpy as np
#matplotlib 
import matplotlib.pyplot as plt

nbins = 144

X = np.loadtxt('cosmics_run357.txt', skiprows=0, unpack=True)

# %%
(hn,hbins,patches) = plt.hist(X, nbins)
plt.title('Number of Hits for Each Module During Cosmic Run 357')
plt.xlabel('Module Number (from 0)')
plt.ylabel('Occurances')
#plt.figure(figsize=[20,10])
fig = plt.gcf()
fig.set_size_inches(14,11)
plt.show()
